# %% [markdown]
# # **1. 머신러닝 소개**

# %% [markdown]
# ![스크린샷 2021-06-26 오후 1.33.40.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2021-06-26 오후 2.20.23.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ![스크린샷 2021-06-26 오후 2.21.23.png](data:image/png;base64,...)

# %% [markdown]
# 예시) 손전등
# 머신러닝은 '어둠'이라는 단어를 말하는 소리 신호를 인식할 때 불이 켜지는데 (중요 키워드가 있어야지 기능을 수행함)
# 딥러닝은 "안 보여", "스위치가 안켜져"라는 신호가 있을 때 스스로 불을 켜야 한다는 것을 인지하고 불을 켠다. (딱 어떠한 키워드가 아니어도 스스로 학습함)
